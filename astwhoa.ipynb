// %%
package main

import (
  "fmt"
  "go/ast"
  "go/parser"
  "go/printer"
  "go/token"
  "log"
  "strings"
  "sort"
  "bytes"
  "testing"
  "bufio"
  "bytes"
  "encoding/json"
  "errors"
  "io/ioutil"
  "log"
  "os"
  "os/exec"
  "path/filepath"
  "time"
  "golang.org/x/tools/go/ast/astutil"
)

// %%
const (
  statPass = "pass"
  statFail = "fail"
  statSkip = "skip"
  statErr  = "error"
)

type testResult struct {
  Name     string `json:"name"`
  Status   string `json:"status"`
  TestCode string `json:"test_code"`
  Message  string `json:"message"`
}

type testReport struct {
  Status  string       `json:"status"`
  Message string       `json:"message,omitempty"`
  Tests   []testResult `json:"tests"`
}

type testLine struct {
  Time    time.Time
  Action  string
  Package string
  Test    string
  Elapsed float64
  Output  string
}

// %%
func splitTestName(testName string) (string, string) {                          
  t := strings.Split(testName, "/")                                             
  if 1 == len(t) {                                                              
    return t[0], ""                                                             
  }                                                                             
  return t[0], t[1]                                                             
}                                                                               
                                                                                
func findTestFile(testName string, codePath string) string {                    
  test, _ := splitTestName(testName)                                            
  files, err := ioutil.ReadDir(codePath)                                        
  if err != nil {                                                               
    log.Printf("warning: input_dir '%s' cannot be read: %s", codePath, err)     
    return ""                                                                   
  }                                                                             
  testdef := fmt.Sprintf("func %s", test)                                       
  for _, f := range files {                                                     
    if strings.HasSuffix(f.Name(), "_test.go") {                                
      var code string                                                           
      testpath := filepath.Join(codePath, f.Name())                             
      fmt.Scanln(&code)                                                         
      fh, err := ioutil.ReadFile(testpath)                                      
      if err != nil {                                                           
        log.Printf("warning: test file '%s' read failed: %s", testpath, err)    
      }                                                                         
      if strings.Contains(string(fh), testdef) {                                
        return testpath                                                         
      }                                                                         
    }                                                                           
  }                                                                             
  log.Printf("warning: test %s not found in input_dir '%s'", codePath, test)    
  return ""                                                                     
}

// %%
func extractTestCode(testName string, testFile string) string {                 
  test, subtest := splitTestName(testName)                                      
  if 0 == len(subtest) {                                                        
    return extractFunc(test, testFile)                                          
  }                                                                             
  subtcode := extractSub(test, subtest, testFile)                               
  if 0 == len(subtcode) {                                                       
    return extractFunc(test, testFile)                                          
  }                                                                             
  return subtcode                                                               
}                                                                               
                                                                                
func extractFunc(testName string, testFile string) string {                     
  fset := token.NewFileSet()                                                    
  ppc := parser.ParseComments                                                   
  if file, err := parser.ParseFile(fset, testFile, nil, ppc); err == nil {      
    for _, d := range file.Decls {                                              
      if f, ok := d.(*ast.FuncDecl); ok && f.Name.Name == testName {            
        fun := &printer.CommentedNode{Node: f, Comments: file.Comments}         
        var buf bytes.Buffer                                                    
        printer.Fprint(&buf, fset, fun)                                         
        return buf.String()                                                     
      }                                                                         
    }                                                                           
  } else {                                                                      
    log.Printf(                                                                 
      "warning: '%s' not parsed from '%s': %s", testName, testFile, err,        
    )                                                                           
  }                                                                             
  return ""                                                                     
}                                                                               
                                                                                
func extractSub(test string, sub string, file string) string {                  
  return sub                                                                    
}

// %%
func getStructure(lines bytes.Buffer, input_dir string) *testReport {
  report := &testReport{
    Status: statPass,
    Tests:  nil,
  }
  defer func() {
    if report.Tests == nil {
      report.Tests = []testResult{}
    }
  }()

  tests, err := buildTests(lines, input_dir)
  if err != nil {
    report.Status = statErr
    report.Message = err.Error()
    return report
  }
  for _, test := range tests {
    if test == nil {
      // just to be sure we dont get a nil pointer exception
      continue
    }
    if test.Status == statErr {
      report.Status = statErr
    }
    if test.Status == statSkip {
      report.Status = statErr
    }
    if report.Status == statPass && test.Status == statFail {
      report.Status = statFail
    }

    report.Tests = append(report.Tests, *test)
  }

  return report
}
func buildTests(lines bytes.Buffer, input_dir string) (map[string]*testResult, error) {
  var (
    tests       = map[string]*testResult{}
    testFileMap = make(map[string]string)
    failMsg     [][]byte
  )

  scanner := bufio.NewScanner(&lines)
  for scanner.Scan() {
    lineBytes := scanner.Bytes()
    var line testLine

    switch {
    case len(lineBytes) == 0:
      continue
    case !bytes.HasPrefix(lineBytes, []byte{'{'}):
      // if the line is not a json, we need to collect the lines to gather why `go test --json` failed
      failMsg = append(failMsg, lineBytes)
      continue
    }

    if err := json.Unmarshal(lineBytes, &line); err != nil {
      log.Println(err)
      continue
    }

    if line.Test == "" {
      continue
    }

    switch line.Action {
    case "run":
      tf, cached := testFileMap[line.Test]
      if !cached {
        tf = findTestFile(input_dir, line.Test)
        testFileMap[line.Test] = tf
      }
      tc := extractTestCode(line.Test, tf)
      if len(tc) > 0 {
        tests[line.Test] = &testResult{
          Name:     line.Test,
          TestCode: tc,
          Status:   statSkip,
        }
      }
    case "output":
      tests[line.Test].Message += "\n" + line.Output
    case statFail:
      tests[line.Test].Status = statFail
    case statPass:
      tests[line.Test].Status = statPass
    }
  }
  if len(failMsg) != 0 {
    return nil, errors.New(string(bytes.Join(failMsg, []byte{'\n'})))
  }
  return tests, nil
}

// %%
const homedir string = "/home/ekingery/"
input_dir := homedir + "dev/exercism/go-test-runner/testdata/concept/conditionals"
output_dir := homedir + "dev/exercism/go-test-runner/outdir"
goExe, err := exec.LookPath("go")
var stdout, stderr bytes.Buffer

  testCmd := &exec.Cmd{
    Dir:    input_dir,
    Path:   goExe,
    Args:   []string{goExe, "test", "--json", "."},
    Stdout: &stdout,
    Stderr: &stderr,
  }
  if err := testCmd.Run(); err != nil {                                         
    if exitError, ok := err.(*exec.ExitError); ok {                             
      if 1 == exitError.ExitCode() {                                            
        // `go test` returns 1 when tests fail                                  
        // The test runner should continue and return 0 in this case            
        log.Printf(                                                             
          "warning: ignoring exit code 1 from '%s'", testCmd.String(),          
        )                                                                       
      } else {                                                                  
        log.Fatalf("'%s' failed with exit code %d: %s",                         
          testCmd.String(), exitError.ExitCode(), err)                          
      }                                                                         
    }                                                                           
  }      
fmt.Println(&stdout)
//output := getStructure(stdout, input_dir)
//bts, err := json.MarshalIndent(output, "", "\t")
// Out:
// {"Time":"2020-12-11T15:07:50.58628809-06:00","Action":"run","Package":"conditionals","Test":"TestNonSubtest"}
// {"Time":"2020-12-11T15:07:50.586922584-06:00","Action":"output","Package":"conditionals","Test":"TestNonSubtest","Output":"=== RUN   TestNonSubtest\n"}
// {"Time":"2020-12-11T15:07:50.586945886-06:00","Action":"output","Package":"conditionals","Test":"TestNonSubtest","Output":"the whole block\n"}
// {"Time":"2020-12-11T15:07:50.58695709-06:00","Action":"output","Package":"conditionals","Test":"TestNonSubtest","Output":"should be returned\n"}
// {"Time":"2020-12-11T15:07:50.586974122-06:00","Action":"output","Package":"conditionals","Test":"TestNonSubtest","Output":"--- PASS: TestNonSubtest (0.00s)\n"}
// {"Time":"2020-12-11T15:07:50.586985973-06:00","Action":"pass","Package":"conditionals","Test":"TestNonSubtest","Elapsed":0}
// {"Time":"2020-12-11T15:07:50.587000689-06:00","Action":"run","Package":"conditionals","Test":"TestParseCard"}
// {"Time":"2020-12-11T15:07:50.587010016-06:00","Action":"output","Package":"conditionals","Test":"TestParseCard","Output":"=== RUN   TestParseCard\n"}
// {"Time":"2020-12-11T15:07:50.587020982-06:00","Action":"run","Package":"conditionals","Test":"TestParseCard/parse_ace"}
// {"Time":"2020-12-11T15:07:50.58703121-06:00","Action":"output","Package":"conditionals","Test":"TestParseCard/parse_ace","Output":"=== RUN   TestParseCard/parse_ace\n"}
// {"Time":"2020-12-11T15:07:50.587042414-06:00","Action":"run","Package":"conditionals","Test":"TestParseCard/parse_two"}
// {"Time":"2020-12-11T15:07:50.587052833-06:00","Action":"output","Package":"conditionals","Test":"TestParseCard/parse_two","Output":"=== RUN   TestParseCard/parse_two\n"}
// {"Time":"2020-12-11T15:07:50.587064725-06:00","Action":"run","Package":"conditionals","Test":"TestParseCard/parse_three"}
// {"Time":"2020-12-11T15:07:50.58707425-06:00","Action":"output","Package":"conditionals","Test":"TestParseCard/parse_three","Output":"=== RUN   TestParseCard/parse_three\n"}
// {"Time":"2020-12-11T15:07:50.587091052-06:00","Action":"run","Package":"conditionals","Test":"TestParseCard/parse_four"}
// {"Time":"2020-12-11T15:07:50.587098132-06:00","Action":"output","Package":"conditionals","Test":"TestParseCard/parse_four","Output":"=== RUN   TestParseCard/parse_four\n"}
// {"Time":"2020-12-11T15:07:50.587104252-06:00","Action":"run","Package":"conditionals","Test":"TestParseCard/parse_five"}
// {"Time":"2020-12-11T15:07:50.587111487-06:00","Action":"output","Package":"conditionals","Test":"TestParseCard/parse_five","Output":"=== RUN   TestParseCard/parse_five\n"}
// {"Time":"2020-12-11T15:07:50.587120416-06:00","Action":"run","Package":"conditionals","Test":"TestParseCard/parse_six"}
// {"Time":"2020-12-11T15:07:50.587125713-06:00","Action":"output","Package":"conditionals","Test":"TestParseCard/parse_six","Output":"=== RUN   TestParseCard/parse_six\n"}
// {"Time":"2020-12-11T15:07:50.587131183-06:00","Action":"run","Package":"conditionals","Test":"TestParseCard/parse_seven"}
// {"Time":"2020-12-11T15:07:50.587136442-06:00","Action":"output","Package":"conditionals","Test":"TestParseCard/parse_seven","Output":"=== RUN   TestParseCard/parse_seven\n"}
// {"Time":"2020-12-11T15:07:50.587146588-06:00","Action":"run","Package":"conditionals","Test":"TestParseCard/parse_eight"}
// {"Time":"2020-12-11T15:07:50.587152303-06:00","Action":"output","Package":"conditionals","Test":"TestParseCard/parse_eight","Output":"=== RUN   TestParseCard/parse_eight\n"}
// {"Time":"2020-12-11T15:07:50.587161928-06:00","Action":"run","Package":"conditionals","Test":"TestParseCard/parse_nine"}
// {"Time":"2020-12-11T15:07:50.587173783-06:00","Action":"output","Package":"conditionals","Test":"TestParseCard/parse_nine","Output":"=== RUN   TestParseCard/parse_nine\n"}
// {"Time":"2020-12-11T15:07:50.587183685-06:00","Action":"run","Package":"conditionals","Test":"TestParseCard/parse_ten"}
// {"Time":"2020-12-11T15:07:50.58719052-06:00","Action":"output","Package":"conditionals","Test":"TestParseCard/parse_ten","Output":"=== RUN   TestParseCard/parse_ten\n"}
// {"Time":"2020-12-11T15:07:50.587283522-06:00","Action":"run","Package":"conditionals","Test":"TestParseCard/parse_jack"}
// {"Time":"2020-12-11T15:07:50.587297847-06:00","Action":"output","Package":"conditionals","Test":"TestParseCard/parse_jack","Output":"=== RUN   TestParseCard/parse_jack\n"}
// {"Time":"2020-12-11T15:07:50.58739748-06:00","Action":"run","Package":"conditionals","Test":"TestParseCard/parse_queen"}
// {"Time":"2020-12-11T15:07:50.587410133-06:00","Action":"output","Package":"conditionals","Test":"TestParseCard/parse_queen","Output":"=== RUN   TestParseCard/parse_queen\n"}
// {"Time":"2020-12-11T15:07:50.587496538-06:00","Action":"run","Package":"conditionals","Test":"TestParseCard/parse_king"}
// {"Time":"2020-12-11T15:07:50.587510313-06:00","Action":"output","Package":"conditionals","Test":"TestParseCard/parse_king","Output":"=== RUN   TestParseCard/parse_king\n"}
// {"Time":"2020-12-11T15:07:50.587585164-06:00","Action":"output","Package":"conditionals","Test":"TestParseCard","Output":"--- PASS: TestParseCard (0.00s)\n"}
// {"Time":"2020-12-11T15:07:50.587619585-06:00","Action":"output","Package":"conditionals","Test":"TestParseCard/parse_ace","Output":"    --- PASS: TestParseCard/parse_ace (0.00s)\n"}
// {"Time":"2020-12-11T15:07:50.587634002-06:00","Action":"pass","Package":"conditionals","Test":"TestParseCard/parse_ace","Elapsed":0}
// {"Time":"2020-12-11T15:07:50.587646156-06:00","Action":"output","Package":"conditionals","Test":"TestParseCard/parse_two","Output":"    --- PASS: TestParseCard/parse_two (0.00s)\n"}
// {"Time":"2020-12-11T15:07:50.587656519-06:00","Action":"pass","Package":"conditionals","Test":"TestParseCard/parse_two","Elapsed":0}
// {"Time":"2020-12-11T15:07:50.587668912-06:00","Action":"output","Package":"conditionals","Test":"TestParseCard/parse_three","Output":"    --- PASS: TestParseCard/parse_three (0.00s)\n"}
// {"Time":"2020-12-11T15:07:50.587681199-06:00","Action":"pass","Package":"conditionals","Test":"TestParseCard/parse_three","Elapsed":0}
// {"Time":"2020-12-11T15:07:50.58769064-06:00","Action":"output","Package":"conditionals","Test":"TestParseCard/parse_four","Output":"    --- PASS: TestParseCard/parse_four (0.00s)\n"}
// {"Time":"2020-12-11T15:07:50.587712003-06:00","Action":"pass","Package":"conditionals","Test":"TestParseCard/parse_four","Elapsed":0}
// {"Time":"2020-12-11T15:07:50.587720589-06:00","Action":"output","Package":"conditionals","Test":"TestParseCard/parse_five","Output":"    --- PASS: TestParseCard/parse_five (0.00s)\n"}
// {"Time":"2020-12-11T15:07:50.587731278-06:00","Action":"pass","Package":"conditionals","Test":"TestParseCard/parse_five","Elapsed":0}
// {"Time":"2020-12-11T15:07:50.587740088-06:00","Action":"output","Package":"conditionals","Test":"TestParseCard/parse_six","Output":"    --- PASS: TestParseCard/parse_six (0.00s)\n"}
// {"Time":"2020-12-11T15:07:50.587752687-06:00","Action":"pass","Package":"conditionals","Test":"TestParseCard/parse_six","Elapsed":0}
// {"Time":"2020-12-11T15:07:50.587763682-06:00","Action":"output","Package":"conditionals","Test":"TestParseCard/parse_seven","Output":"    --- PASS: TestParseCard/parse_seven (0.00s)\n"}
// {"Time":"2020-12-11T15:07:50.587777013-06:00","Action":"pass","Package":"conditionals","Test":"TestParseCard/parse_seven","Elapsed":0}
// {"Time":"2020-12-11T15:07:50.58778696-06:00","Action":"output","Package":"conditionals","Test":"TestParseCard/parse_eight","Output":"    --- PASS: TestParseCard/parse_eight (0.00s)\n"}
// {"Time":"2020-12-11T15:07:50.587797108-06:00","Action":"pass","Package":"conditionals","Test":"TestParseCard/parse_eight","Elapsed":0}
// {"Time":"2020-12-11T15:07:50.587805738-06:00","Action":"output","Package":"conditionals","Test":"TestParseCard/parse_nine","Output":"    --- PASS: TestParseCard/parse_nine (0.00s)\n"}
// {"Time":"2020-12-11T15:07:50.587818471-06:00","Action":"pass","Package":"conditionals","Test":"TestParseCard/parse_nine","Elapsed":0}
// {"Time":"2020-12-11T15:07:50.587827921-06:00","Action":"output","Package":"conditionals","Test":"TestParseCard/parse_ten","Output":"    --- PASS: TestParseCard/parse_ten (0.00s)\n"}
// {"Time":"2020-12-11T15:07:50.587837887-06:00","Action":"pass","Package":"conditionals","Test":"TestParseCard/parse_ten","Elapsed":0}
// {"Time":"2020-12-11T15:07:50.58784899-06:00","Action":"output","Package":"conditionals","Test":"TestParseCard/parse_jack","Output":"    --- PASS: TestParseCard/parse_jack (0.00s)\n"}
// {"Time":"2020-12-11T15:07:50.58785881-06:00","Action":"pass","Package":"conditionals","Test":"TestParseCard/parse_jack","Elapsed":0}
// {"Time":"2020-12-11T15:07:50.587870285-06:00","Action":"output","Package":"conditionals","Test":"TestParseCard/parse_queen","Output":"    --- PASS: TestParseCard/parse_queen (0.00s)\n"}
// {"Time":"2020-12-11T15:07:50.587879926-06:00","Action":"pass","Package":"conditionals","Test":"TestParseCard/parse_queen","Elapsed":0}
// {"Time":"2020-12-11T15:07:50.587891104-06:00","Action":"output","Package":"conditionals","Test":"TestParseCard/parse_king","Output":"    --- PASS: TestParseCard/parse_king (0.00s)\n"}
// {"Time":"2020-12-11T15:07:50.587906668-06:00","Action":"pass","Package":"conditionals","Test":"TestParseCard/parse_king","Elapsed":0}
// {"Time":"2020-12-11T15:07:50.587918704-06:00","Action":"pass","Package":"conditionals","Test":"TestParseCard","Elapsed":0}
// {"Time":"2020-12-11T15:07:50.587927171-06:00","Action":"run","Package":"conditionals","Test":"TestBlackjack"}
// {"Time":"2020-12-11T15:07:50.587938101-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack","Output":"=== RUN   TestBlackjack\n"}
// {"Time":"2020-12-11T15:07:50.587947565-06:00","Action":"run","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)"}
// {"Time":"2020-12-11T15:07:50.587958397-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)","Output":"=== RUN   TestBlackjack/blackjack_with_ten_(ace_first)\n"}
// {"Time":"2020-12-11T15:07:50.588031165-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack","Output":"--- FAIL: TestBlackjack (0.00s)\n"}
// {"Time":"2020-12-11T15:07:50.588048156-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)","Output":"    --- FAIL: TestBlackjack/blackjack_with_ten_(ace_first) (0.00s)\n"}
// {"Time":"2020-12-11T15:07:50.590337226-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)","Output":"panic: Please implement the IsBlackjack function [recovered]\n"}
// {"Time":"2020-12-11T15:07:50.590409644-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)","Output":"\tpanic: Please implement the IsBlackjack function\n"}
// {"Time":"2020-12-11T15:07:50.590469799-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)","Output":"\n"}
// {"Time":"2020-12-11T15:07:50.590510882-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)","Output":"goroutine 34 [running]:\n"}
// {"Time":"2020-12-11T15:07:50.590554105-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)","Output":"testing.tRunner.func1.1(0x5111a0, 0x56a200)\n"}
// {"Time":"2020-12-11T15:07:50.59059204-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)","Output":"\t/usr/lib/go-1.14/src/testing/testing.go:988 +0x30d\n"}
// {"Time":"2020-12-11T15:07:50.590649896-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)","Output":"testing.tRunner.func1(0xc000141320)\n"}
// {"Time":"2020-12-11T15:07:50.590694349-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)","Output":"\t/usr/lib/go-1.14/src/testing/testing.go:991 +0x3f9\n"}
// {"Time":"2020-12-11T15:07:50.590739987-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)","Output":"panic(0x5111a0, 0x56a200)\n"}
// {"Time":"2020-12-11T15:07:50.590780964-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)","Output":"\t/usr/lib/go-1.14/src/runtime/panic.go:969 +0x166\n"}
// {"Time":"2020-12-11T15:07:50.590814755-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)","Output":"conditionals.IsBlackjack(...)\n"}
// {"Time":"2020-12-11T15:07:50.590850364-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)","Output":"\t/home/ekingery/dev/exercism/go-test-runner/testdata/concept/conditionals/conditionals.go:35\n"}
// {"Time":"2020-12-11T15:07:50.590898338-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)","Output":"conditionals.TestBlackjack.func1(0xc000141320)\n"}
// {"Time":"2020-12-11T15:07:50.590939313-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)","Output":"\t/home/ekingery/dev/exercism/go-test-runner/testdata/concept/conditionals/conditionals_test.go:177 +0x39\n"}
// {"Time":"2020-12-11T15:07:50.59097613-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)","Output":"testing.tRunner(0xc000141320, 0xc00010aa60)\n"}
// {"Time":"2020-12-11T15:07:50.591033003-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)","Output":"\t/usr/lib/go-1.14/src/testing/testing.go:1039 +0xdc\n"}
// {"Time":"2020-12-11T15:07:50.591067846-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)","Output":"created by testing.(*T).Run\n"}
// {"Time":"2020-12-11T15:07:50.591130244-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)","Output":"\t/usr/lib/go-1.14/src/testing/testing.go:1090 +0x372\n"}
// {"Time":"2020-12-11T15:07:50.592097639-06:00","Action":"fail","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)","Elapsed":0}
// {"Time":"2020-12-11T15:07:50.592175564-06:00","Action":"fail","Package":"conditionals","Test":"TestBlackjack","Elapsed":0}
// {"Time":"2020-12-11T15:07:50.592197738-06:00","Action":"output","Package":"conditionals","Output":"FAIL\tconditionals\t0.008s\n"}
// {"Time":"2020-12-11T15:07:50.592221899-06:00","Action":"fail","Package":"conditionals","Elapsed":0.008}
// 14497 <nil>

// %%
testName := "TestParseCard"
testFile := homedir + "dev/exercism/go-test-runner/testdata/concept/conditionals/conditionals_test.go"
testCodeSrc := extractFunc(testName, testFile)
fmt.Println(testCodeSrc)
// Out:
// func TestParseCard(t *testing.T) {
// 	tests := []struct {
// 		name	string	`json:"name"`
// 		card	string	`json:"card"`
// 		want	int	`json:"want"`
// 	}{
// 		{
// 			name:	"parse ace",
// 			card:	"ace",
// 			want:	11,
// 		},
// 		{
// 			name:	"parse two",
// 			card:	"two",
// 			want:	2,
// 		},
// 		{
// 			name:	"parse three",
// 			card:	"three",
// 			want:	3,
// 		},
// 		{
// 			name:	"parse four",
// 			card:	"four",
// 			want:	4,
// 		},
// 		{
// 			name:	"parse five",
// 			card:	"five",
// 			want:	5,
// 		},
// 		{
// 			name:	"parse six",
// 			card:	"six",
// 			want:	6,
// 		},
// 		{
// 			name:	"parse seven",
// 			card:	"seven",
// 			want:	7,
// 		},
// 		{
// 			name:	"parse eight",
// 			card:	"eight",
// 			want:	8,
// 		},
// 		{
// 			name:	"parse nine",
// 			card:	"nine",
// 			want:	9,
// 		},
// 		{
// 			name:	"parse ten",
// 			card:	"ten",
// 			want:	10,
// 		},
// 		{
// 			name:	"parse jack",
// 			card:	"jack",
// 			want:	10,
// 		},
// 		{
// 			name:	"parse queen",
// 			card:	"queen",
// 			want:	10,
// 		},
// 		{
// 			name:	"parse king",
// 			card:	"king",
// 			want:	10,
// 		},
// 	}
// 	for _, tt := range tests {
// 		t.Run(tt.name, func(t *testing.T) {
// 			if got := ParseCard(tt.card); got != tt.want {
// 				t.Errorf("ParseCard(%s) = %d, want %d", tt.card, got, tt.want)
// 			}
// 		})
// 	}
// }
// 1140 <nil>

// %%
fset := token.NewFileSet()
f, err := parser.ParseFile(fset, "", "package main\n" + testCodeSrc, parser.ParseComments)
if err != nil {
    log.Fatal(err)
}
fexp, err := parser.ParseExpr(testCodeSrc)

// %%
fmt.Printf("%T, %s\n--\n", f, f)

fmt.Printf("%T, %s", fexp, fexp)
// Out:
// *ast.File, &{%!s(*ast.CommentGroup=<nil>) %!s(token.Pos=1) main [%!s(*ast.FuncDecl=&{<nil> <nil> 0xc00061fea0 0xc0006671a0 0xc000664f60})] scope 0xc000626740 {
// 	func TestParseCard
// }
//  [] [testing string string int testing ParseCard] []}
// --
// *ast.FuncLit, &{%!s(*ast.FuncType=&{1 0xc000665170 <nil>}) %!s(*ast.BlockStmt=&{34 [0xc00066a180 0xc000623d60] 1139})}
// 118 <nil>

// %%
var tdAssgn ast.AssignStmt
var tdNode ast.Node
var tda ast.AssignStmt
var tdn ast.Node

ast.Inspect(fexp, func(n ast.Node) bool {
    switch x := n.(type) {
    case *ast.BasicLit:
        if x != nil && token.STRING == x.Kind && "\"parse queen\"" == x.Value{
            fmt.Printf("bl %s:\t%s - %s\n", fset.Position(n.Pos()), x.Kind, x.Value)
            tdAssgn = tda
            tdNode = tdn
            return false
        }
    case *ast.AssignStmt:
        if x != nil {
            fmt.Printf("asgn %s: %s - %s\n", fset.Position(n.Pos()), x.Lhs, x.Rhs)
        }
        tda = *x
        tdn = n
		/*case *ast.Ident:
            if x != nil && "tests" == x.Name {
                fmt.Printf("id %s: %s\n", fset.Position(n.Pos()), x.Name)
            } */
	}
	return true
})
LHE := tdAssgn.Lhs[0]
fmt.Printf("%T, %s", LHE, LHE)

//fmt.Printf("tdata name: %s: %s - %s\n", fset.Position(tdNode.Pos()), tdAssgn.Lhs, tdAssgn.Rhs)
//fmt.Printf("asgn %s: %s - %s\n", fset.Position(tdNode.Pos()), tdAssgn.Lhs, tdAssgn.Rhs)
//fmt.Printf("asgn %s: %s - %s\n", fset.Position(tdNode.Pos()), tdAssgn.TokPos, tdAssgn.Tok)
// Out:
// asgn 2:24: [tests] - [%!s(*ast.CompositeLit=&{0xc000665200 140 [0xc000625ac0 0xc000625b40 0xc000625bc0 0xc000625c80 0xc000625d00 0xc000625d80 0xc000625e00 0xc000625e80 0xc000625f00 0xc000625f80 0xc00066a000 0xc00066a080 0xc00066a100] 941 false})]
// bl 63:1:	STRING - "parse queen"
// asgn 75:32: [got] - [%!s(*ast.CallExpr=&{0xc00066c280 1031 [0xc00066c2e0] 0 1039})]
// *ast.Ident, tests
// 17 <nil>

// %%
//ast.Print(nil, fexp)
//var tdAssgn ast.AssignStmt
type storedNodes struct {
    subtest_name  ast.Node
    test_assign   ast.Node
    loop_varname  string
} 

var tdNode ast.Node
var tdPNode ast.Node
var tda ast.AssignStmt
var tdn ast.Node


astutil.Apply(fexp, func(cr *astutil.Cursor) bool {
    n := cr.Node()
    //n := cr.Parent()
    switch x := n.(type) {
    case *ast.BasicLit:
        if x != nil && token.STRING == x.Kind && "\"parse queen\"" == x.Value{
            fmt.Printf("bl %s:\t%s - %s\n", fset.Position(n.Pos()), x.Kind, x.Value)
            //tdAssgn = cr.Parent()
            tdPNode = cr.Parent()
            //return false
        }
    case *ast.AssignStmt:
        if x != nil {
            fmt.Printf("asgn %s: %s - %s\n", fset.Position(n.Pos()), x.Lhs, x.Rhs)
        }
        tda = *x
        tdn = n
		/*case *ast.Ident:
            if x != nil && "tests" == x.Name {
                fmt.Printf("id %s: %s\n", fset.Position(n.Pos()), x.Name)
            } */
	}
	return true
    
    /*
    p, ok := cr.Parent().(*ast.BinaryExpr)
    if !ok {
        return true
    }
    //ast.Print(nil, p)
    fmt.Println(cr.Name())
    fmt.Println(p.Op)

    /*if p.Op == token.ADD {
        cr.Replace(&ast.BasicLit{
            Kind:  token.INT,
            Value: "2",
        })
        return false
    }
    */
}, nil)
fmt.Println("whoa")
fmt.Println(tdPNode)
fmt.Printf("%T, %s", tdPNode, tdPNode)
//ast.Print(nil, fexp)
// Out:
// asgn 2:24: [tests] - [%!s(*ast.CompositeLit=&{0xc000665200 140 [0xc000625ac0 0xc000625b40 0xc000625bc0 0xc000625c80 0xc000625d00 0xc000625d80 0xc000625e00 0xc000625e80 0xc000625f00 0xc000625f80 0xc00066a000 0xc00066a080 0xc00066a100] 941 false})]
// bl 63:1:	STRING - "parse queen"
// asgn 75:32: [got] - [%!s(*ast.CallExpr=&{0xc00066c280 1031 [0xc00066c2e0] 0 1039})]
// whoa
// &{name 825 0xc000667ea0}
// *ast.KeyValueExpr, &{name %!s(token.Pos=825) %!s(*ast.BasicLit=&{827 9 "parse queen"})}
// 87 <nil>

// %%
astutil.Apply(fexp, func(cr *astutil.Cursor) bool {
    n := cr.Node()
    //n := cr.Parent()
    switch x := n.(type) {
    case *ast.BasicLit:
        if x != nil && token.STRING == x.Kind && "\"parse queen\"" == x.Value{
            fmt.Printf("bl %s:\t%s - %s\n", fset.Position(n.Pos()), x.Kind, x.Value)
            //tdAssgn = cr.Parent()
            tdPNode = cr.Parent()
            //return false
        }
    case *ast.AssignStmt:
        if x != nil {
            fmt.Printf("asgn %s: %s - %s\n", fset.Position(n.Pos()), x.Lhs, x.Rhs)
        }
        tda = *x
        tdn = n
    case *ast.ExprStmt:
        if x != nil {
            fmt.Printf("exprst %s: %s - %s\n", fset.Position(n.Pos()), x.X, "")
        }
	}
	return true
}, nil)

var abuf bytes.Buffer
printer.Fprint(&abuf, fset, fexp)
fmt.Println("after\n----\n", abuf.String())
//printer.Fprint(&buf, fset, fun)
// Out:
// asgn 2:24: [tests] - [%!s(*ast.CompositeLit=&{0xc000520660 140 [0xc000610340 0xc0006103c0 0xc000610440 0xc000610540 0xc0006105c0 0xc000610640 0xc0006106c0 0xc000610740 0xc0006107c0 0xc000610840 0xc0006108c0 0xc000610940 0xc0006109c0] 941 false})]
// bl 63:1:	STRING - "parse queen"
// exprst 74:18: &{%!s(*ast.SelectorExpr=&{0xc00078d240 0xc00078d260}) %!s(token.Pos=978) [%!s(*ast.SelectorExpr=&{0xc00078d2a0 0xc00078d2c0}) %!s(*ast.FuncLit=&{0xc00078d3a0 0xc0001e71a0})] %!s(token.Pos=0) %!s(token.Pos=1134)} -
// asgn 75:32: [got] - [%!s(*ast.CallExpr=&{0xc00078d3e0 1031 [0xc00078d440] 0 1039})]
// exprst 76:42: &{%!s(*ast.SelectorExpr=&{0xc00078d4e0 0xc00078d500}) %!s(token.Pos=1071) [%!s(*ast.BasicLit=&{1072 9 "ParseCard(%s) = %d, want %d"}) %!s(*ast.SelectorExpr=&{0xc00078d560 0xc00078d580}) got %!s(*ast.SelectorExpr=&{0xc00078d600 0xc00078d620})] %!s(token.Pos=0) %!s(token.Pos=1124)} -
// after
// ----
//  func(
// 	_ testing.T) {
// 	tests := []struct {
// 		name	string	`json:"name"`
// 		card	string	`json:"card"`
// 		want	int	`json:"want"`
// 	}{{name: "parse ace",
// 		card:	"ace",
// 		want:	11,
// 	}, {name: "parse two",
// 		card:	"two",
// 		want:	2,
// 	}, {name: "parse three",
// 		card:	"three",
// 		want:	3,
// 	}, {name: "parse four",
// 		card:	"four",
// 		want:	4,
// 	}, {name: "parse five",
// 		card:	"five",
// 		want:	5,
// 	}, {name: "parse six",
// 		card:	"six",
// 		want:	6,
// 	}, {name: "parse seven",
// 		card:	"seven",
// 		want:	7,
// 	}, {name: "parse eight",
// 		card:	"eight",
// 		want:	8,
// 	}, {name: "parse nine",
// 		card:	"nine",
// 		want:	9,
// 	}, {name: "parse ten",
// 		card:	"ten",
// 		want:	10,
// 	}, {name: "parse jack",
// 		card:	"jack",
// 		want:	10,
// 	}, {name: "parse queen",
// 		card:	"queen",
// 		want:	10,
// 	}, {name: "parse king",
// 		card:	"king",
// 		want:	10,
// 	}}
// 	for _, tt := range tests {
// 		t.Run(tt.name,
// 			func(t *testing.T) {
// 				if got :=
// 					ParseCard(tt.card); got != tt.want {
// 					t.Errorf(
// 						"ParseCard(%s) = %d, want %d", tt.card, got, tt.want)
// 				}
// 			})
// 	}
// }
// 1037 <nil>

// %%
// golang test_code extraction pseudocode
        
// 1) Inspect the AST for the full test function using ast.Inspect(): 
//       
//    find the AssignStmt with a LHS containing the "original test data []struct name" and 
//        the RHS containing a *ast.CompositeLit matching the subtest name
//        (need to sub underscores for spaces and search for both)
//    __Store__ the "original test data []struct" name, "tests AssignStmt" node, and the "subtest data" *ast.CompositeLit node
//    find the *ast.RangeStmt with X == "original test data []struct name"
//    __Store__ the "test loop range statement node"
//    __Store__ the *ast.RangeStmt.Value "new test data struct name"
//    Traverse the RangeStmt.Body - the next node should be the *ast.CallExpr for Run()
//    Traverse the Run() *ast.CallExpr to arrive at the closure passed to the Run(): *ast.FuncLit
//    __Store__ the *ast.FuncLit.Body "Run() function literal node"
//
// 2) Edit the AST for the full test function using astutil.Apply(): 
//
//    find the "tests AssignStmt" node
//      - replace it with a new struct named "new test data struct name" and assign it "subtest data"
//
//    find the "test loop range statement node"
//      - replace it with the "Run() function literal node"
type testMeta struct {
    subTName    string           // name of subtest
    origTDName  string           // original test data []struct name
    newTDName   string           // new test data struct name
    TDAssign    ast.Node         // tests AssignStmt
    subTest     ast.CompositeLit // Run() function literal node
    rangeStmt   ast.RangeStmt    // test loop range statement node
} 

metadata := testMeta{
    subTName: "parse queen",
}

fset := token.NewFileSet()
f, err := parser.ParseFile(fset, "", "package main\n" + testCodeSrc, parser.ParseComments)
if err != nil {
    log.Fatal(err)
}

fexp, err := parser.ParseExpr(testCodeSrc)

ast.Inspect(fexp, func(n ast.Node) bool {
    switch x := n.(type) {
    case *ast.RangeStmt:        
        fmt.Printf("range %s:\t%s - %s\n", fset.Position(n.Pos()), x.X, x.Body)
        // List : []ast.Stmt(len = 1)
        // - grab the value (tt), and use it to name the test struct
        //   1 : *ast.RangeStmt (Tok: :=)
        //   Key : *ast.Ident (Name: _)
        //   Value : *ast.Ident (Name: tt)
        //     Obj : *ast.Object (Kind: var, Name: tt)
        
        // Main Body: *ast.BlockStmt - List [2]: 
        // - first node: []ast.Stmt(len = 1)
        //    - *ast.RangeStmt (Tok: :=)  [[[[[----this is the thing we want to replace-----]]]]]

        // range.body.list[1]
          // contains the Run, replace it with the body of the run...
        
        // range.body.list.[]ast.Stmt(len = 1) 
           // this list contains - *ast.ExprStmt - standalone expression in a statement list
        // *ast.ExprStmt.X is an *ast.CallExpr (to run())
        //    *ast.CallExpr.Fun -> *ast.SelectorExpr 
        //        - *ast.SelectorExpr.X = identifier t (in t.Run())
        //        - *ast.SelectorExpr.Sel = Name "Run" in t.Run()
        //    *ast.CallExpr.Args is an []ast.Expr(len = 2) which is the 2 args to t.Run(tt.name, func(t *testing.T)
        //        - 0: *ast.SelectorExpr.Sel = Name "tt.name" in t.Run()
        //        - 1: *ast.FuncLit *ast.Expr
        //              - Type: *ast.FuncType
        //               Body : *ast.BlockStmt [[[[[----the thing we want to use to replace the range stmt-----]]]]]
        //                 List : []ast.Stmt(len = 0)
    case *ast.BasicLit:
        if token.STRING == x.Kind && "\"parse queen\"" == x.Value {
            fmt.Printf("bl %s:\t%s - %s\n", fset.Position(n.Pos()), x.Kind, x.Value)
            //tdAssgn = cr.Parent()
            //tdPNode = cr.Parent()
            metadata.origTDName = "parse queen"
            //return false
        }
    case *ast.AssignStmt:
        if metadata.TDAssign == nil {
            //[TODO - search and assign]
            fmt.Printf("asgn %s: %s - %s\n", fset.Position(n.Pos()), x.Lhs, x.Rhs)
            metadata.TDAssign = n
        }
//    find the AssignStmt with a LHS containing the "original test data []struct name" and 
//        the RHS containing a *ast.CompositeLit matching the subtest name
//        (need to sub underscores for spaces and search for both)
//    __Store__ the "original test data []struct" name, "tests AssignStmt" node, and the "subtest data" *ast.CompositeLit node

    //case *ast.ExprStmt:
     //   fmt.Printf("exprst %s: %s - %s\n", fset.Position(n.Pos()), x.X, "")
    //case *ast.RangeStmt:
        //fmt.Printf("exprst %s: %s - %s\n", fset.Position(n.Pos()), x.X, "")
    }
    return true
})

fmt.Println("-----\n")
fmt.Printf("%+v\n", metadata)
/*var abuf bytes.Buffer
printer.Fprint(&abuf, fset, fun)
fmt.Println("after\n----\n", buf.String())
*/
// Out:
// asgn 2:24: [tests] - [%!s(*ast.CompositeLit=&{0xc0007bb170 140 [0xc00086a000 0xc00086a080 0xc00086a100 0xc00086a1c0 0xc00086a240 0xc00086a2c0 0xc00086a340 0xc00086a400 0xc00086a480 0xc00086a500 0xc00086a580 0xc00086a600 0xc00086a680] 941 false})]
// bl 63:1:	STRING - "parse queen"
// range 71:10:	tests - &{%!s(token.Pos=969) [%!s(*ast.ExprStmt=&{0xc00086a900})] %!s(token.Pos=1137)}
// -----
//
// {𒀸subTName:parse queen 𒀸origTDName:parse queen 𒀸newTDName: TDAssign:0xc00086a700 𒀸subTest:{Type:<nil> Lbrace:0 Elts:[] Rbrace:0 Incomplete:false} 𒀸rangeStmt:{For:0 Key:<nil> Value:<nil> TokPos:0 Tok:ILLEGAL X:<nil> Body:<nil>}}
// 243 <nil>

// %%
// exp, err := parser.ParseExpr(testCodeSrc)
testdataAST := f.Decls[0].(*ast.FuncDecl).Body.List[0]
rangeAST := f.Decls[0].(*ast.FuncDecl).Body.List[1]
var buf bytes.Buffer
printer.Fprint(&buf, fset, testdataAST)
fmt.Printf("type %T: %s", testdataAST, buf.String())
buf.Reset()
printer.Fprint(&buf, fset, rangeAST)
fmt.Printf("type %T: %s", rangeAST, buf.String())
// Out:
// type *ast.AssignStmt: tests := []struct {
// 	name	string	`json:"name"`
// 	card	string	`json:"card"`
// 	want	int	`json:"want"`
// }{
// 	{
// 		name:	"parse ace",
// 		card:	"ace",
// 		want:	11,
// 	},
// 	{
// 		name:	"parse two",
// 		card:	"two",
// 		want:	2,
// 	},
// 	{
// 		name:	"parse three",
// 		card:	"three",
// 		want:	3,
// 	},
// 	{
// 		name:	"parse four",
// 		card:	"four",
// 		want:	4,
// 	},
// 	{
// 		name:	"parse five",
// 		card:	"five",
// 		want:	5,
// 	},
// 	{
// 		name:	"parse six",
// 		card:	"six",
// 		want:	6,
// 	},
// 	{
// 		name:	"parse seven",
// 		card:	"seven",
// 		want:	7,
// 	},
// 	{
// 		name:	"parse eight",
// 		card:	"eight",
// 		want:	8,
// 	},
// 	{
// 		name:	"parse nine",
// 		card:	"nine",
// 		want:	9,
// 	},
// 	{
// 		name:	"parse ten",
// 		card:	"ten",
// 		want:	10,
// 	},
// 	{
// 		name:	"parse jack",
// 		card:	"jack",
// 		want:	10,
// 	},
// 	{
// 		name:	"parse queen",
// 		card:	"queen",
// 		want:	10,
// 	},
// 	{
// 		name:	"parse king",
// 		card:	"king",
// 		want:	10,
// 	},
// }type *ast.RangeStmt: for _, tt := range tests {
// 	t.Run(tt.name, func(t *testing.T) {
// 		if got := ParseCard(tt.card); got != tt.want {
// 			t.Errorf("ParseCard(%s) = %d, want %d", tt.card, got, tt.want)
// 		}
// 	})
// }
// 209 <nil>
