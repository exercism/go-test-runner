// %% [markdown]
// # AST debugging using interactive Go
//
// This code was used in the original development of the AST parsing performed by the [Exercism Go Test Runner](https://github.com/exercism/go-test-runner/). It uses the [gophernotes project](https://github.com/gopherdata/gophernotes). Consult the gophernotes docs for installation instructions. Once installed, you should be able to execute and modify the following debug code "live".

// %%
package main

import (
  "bytes"
  "fmt"
  "go/ast"
  "go/parser"
  "go/printer"
  "go/token"
  "go/format"
  "log"
  "os"
  "os/exec"
  "os/user"
  "strings"
  "strconv"
  "golang.org/x/tools/go/ast/astutil"
  "github.com/exercism/go-test-runner/testrunner"  // uses the main branch of the published package
  // "testrunner"
  // Alternatively, comment out the github import and use your local copy by 
  // symlinking the testrunner directory from your local repo to $GOPATH/src
  // 
  // If you import the local package, after making a change 
  // you will need to stop the kernel and re-run this cell to rebuild the package
  // For a faster development cycle, copy the functions you are working on to a new cell
  // and call the local version instead
)

// %%
// Run the test command, view the output and test out the extraction code
cwd, err := os.Getwd()
if err != nil {
    fmt.Println(err)
}
input_dir := cwd + "/testdata/concept/conditionals"
output_dir := cwd + "/outdir"
testName := "TestParseCard"
testFile := cwd + "/testdata/concept/conditionals/conditionals_test.go"
testCodeSrc := testrunner.ExtractTestCode(testName, testFile)
goExe, err := exec.LookPath("go")
var stdout, stderr bytes.Buffer

  testCmd := &exec.Cmd{
    Dir:    input_dir,
    Path:   goExe,
    Args:   []string{goExe, "test", "--json", "."},
    Stdout: &stdout,
    Stderr: &stderr,
  }
  if err := testCmd.Run(); err != nil {                                         
    if exitError, ok := err.(*exec.ExitError); ok {                             
      if 1 == exitError.ExitCode() {                                            
        // `go test` returns 1 when tests fail                                  
        // The test runner should continue and return 0 in this case            
        log.Printf(                                                             
          "warning: ignoring exit code 1 from '%s'", testCmd.String(),          
        )                                                                       
      } else {                                                                  
        log.Fatalf("'%s' failed with exit code %d: %s",                         
          testCmd.String(), exitError.ExitCode(), err)                          
      }                                                                         
    }                                                                           
  }      
fmt.Println("go test --json output:\n", &stdout)
fmt.Println("\n------\n")
fmt.Println("extracted test function:\n", testCodeSrc)
// Out:
// go test --json output:
//  {"Time":"2021-01-19T13:46:01.680968-06:00","Action":"run","Package":"conditionals","Test":"TestNonSubtest"}
// {"Time":"2021-01-19T13:46:01.681299-06:00","Action":"output","Package":"conditionals","Test":"TestNonSubtest","Output":"=== RUN   TestNonSubtest\n"}
// {"Time":"2021-01-19T13:46:01.681316-06:00","Action":"output","Package":"conditionals","Test":"TestNonSubtest","Output":"the whole block\n"}
// {"Time":"2021-01-19T13:46:01.681321-06:00","Action":"output","Package":"conditionals","Test":"TestNonSubtest","Output":"should be returned\n"}
// {"Time":"2021-01-19T13:46:01.681333-06:00","Action":"output","Package":"conditionals","Test":"TestNonSubtest","Output":"--- PASS: TestNonSubtest (0.00s)\n"}
// {"Time":"2021-01-19T13:46:01.681337-06:00","Action":"pass","Package":"conditionals","Test":"TestNonSubtest","Elapsed":0}
// {"Time":"2021-01-19T13:46:01.681351-06:00","Action":"run","Package":"conditionals","Test":"TestTODOSubtest"}
// {"Time":"2021-01-19T13:46:01.681354-06:00","Action":"output","Package":"conditionals","Test":"TestTODOSubtest","Output":"=== RUN   TestTODOSubtest\n"}
// {"Time":"2021-01-19T13:46:01.681358-06:00","Action":"run","Package":"conditionals","Test":"TestTODOSubtest/parse_ace"}
// {"Time":"2021-01-19T13:46:01.681362-06:00","Action":"output","Package":"conditionals","Test":"TestTODOSubtest/parse_ace","Output":"=== RUN   TestTODOSubtest/parse_ace\n"}
// {"Time":"2021-01-19T13:46:01.681366-06:00","Action":"output","Package":"conditionals","Test":"TestTODOSubtest/parse_ace","Output":"the whole block\n"}
// {"Time":"2021-01-19T13:46:01.68137-06:00","Action":"output","Package":"conditionals","Test":"TestTODOSubtest/parse_ace","Output":"should be returned\n"}
// {"Time":"2021-01-19T13:46:01.681377-06:00","Action":"output","Package":"conditionals","Test":"TestTODOSubtest","Output":"--- PASS: TestTODOSubtest (0.00s)\n"}
// {"Time":"2021-01-19T13:46:01.681383-06:00","Action":"output","Package":"conditionals","Test":"TestTODOSubtest/parse_ace","Output":"    --- PASS: TestTODOSubtest/parse_ace (0.00s)\n"}
// {"Time":"2021-01-19T13:46:01.681392-06:00","Action":"pass","Package":"conditionals","Test":"TestTODOSubtest/parse_ace","Elapsed":0}
// {"Time":"2021-01-19T13:46:01.681396-06:00","Action":"pass","Package":"conditionals","Test":"TestTODOSubtest","Elapsed":0}
// {"Time":"2021-01-19T13:46:01.6814-06:00","Action":"run","Package":"conditionals","Test":"TestParseCard"}
// {"Time":"2021-01-19T13:46:01.681403-06:00","Action":"output","Package":"conditionals","Test":"TestParseCard","Output":"=== RUN   TestParseCard\n"}
// {"Time":"2021-01-19T13:46:01.681407-06:00","Action":"run","Package":"conditionals","Test":"TestParseCard/parse_two"}
// {"Time":"2021-01-19T13:46:01.68141-06:00","Action":"output","Package":"conditionals","Test":"TestParseCard/parse_two","Output":"=== RUN   TestParseCard/parse_two\n"}
// {"Time":"2021-01-19T13:46:01.681416-06:00","Action":"run","Package":"conditionals","Test":"TestParseCard/parse_jack"}
// {"Time":"2021-01-19T13:46:01.681421-06:00","Action":"output","Package":"conditionals","Test":"TestParseCard/parse_jack","Output":"=== RUN   TestParseCard/parse_jack\n"}
// {"Time":"2021-01-19T13:46:01.681426-06:00","Action":"run","Package":"conditionals","Test":"TestParseCard/parse_king"}
// {"Time":"2021-01-19T13:46:01.681429-06:00","Action":"output","Package":"conditionals","Test":"TestParseCard/parse_king","Output":"=== RUN   TestParseCard/parse_king\n"}
// {"Time":"2021-01-19T13:46:01.681433-06:00","Action":"output","Package":"conditionals","Test":"TestParseCard","Output":"--- PASS: TestParseCard (0.00s)\n"}
// {"Time":"2021-01-19T13:46:01.681436-06:00","Action":"output","Package":"conditionals","Test":"TestParseCard/parse_two","Output":"    --- PASS: TestParseCard/parse_two (0.00s)\n"}
// {"Time":"2021-01-19T13:46:01.68144-06:00","Action":"pass","Package":"conditionals","Test":"TestParseCard/parse_two","Elapsed":0}
// {"Time":"2021-01-19T13:46:01.68145-06:00","Action":"output","Package":"conditionals","Test":"TestParseCard/parse_jack","Output":"    --- PASS: TestParseCard/parse_jack (0.00s)\n"}
// {"Time":"2021-01-19T13:46:01.681456-06:00","Action":"pass","Package":"conditionals","Test":"TestParseCard/parse_jack","Elapsed":0}
// {"Time":"2021-01-19T13:46:01.681461-06:00","Action":"output","Package":"conditionals","Test":"TestParseCard/parse_king","Output":"    --- PASS: TestParseCard/parse_king (0.00s)\n"}
// {"Time":"2021-01-19T13:46:01.681464-06:00","Action":"pass","Package":"conditionals","Test":"TestParseCard/parse_king","Elapsed":0}
// {"Time":"2021-01-19T13:46:01.681468-06:00","Action":"pass","Package":"conditionals","Test":"TestParseCard","Elapsed":0}
// {"Time":"2021-01-19T13:46:01.681471-06:00","Action":"run","Package":"conditionals","Test":"TestBlackjack"}
// {"Time":"2021-01-19T13:46:01.681474-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack","Output":"=== RUN   TestBlackjack\n"}
// {"Time":"2021-01-19T13:46:01.681502-06:00","Action":"run","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)"}
// {"Time":"2021-01-19T13:46:01.681512-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)","Output":"=== RUN   TestBlackjack/blackjack_with_ten_(ace_first)\n"}
// {"Time":"2021-01-19T13:46:01.681535-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack","Output":"--- FAIL: TestBlackjack (0.00s)\n"}
// {"Time":"2021-01-19T13:46:01.681543-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)","Output":"    --- FAIL: TestBlackjack/blackjack_with_ten_(ace_first) (0.00s)\n"}
// {"Time":"2021-01-19T13:46:01.68372-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)","Output":"panic: Please implement the IsBlackjack function [recovered]\n"}
// {"Time":"2021-01-19T13:46:01.683748-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)","Output":"\tpanic: Please implement the IsBlackjack function\n"}
// {"Time":"2021-01-19T13:46:01.683759-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)","Output":"\n"}
// {"Time":"2021-01-19T13:46:01.68378-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)","Output":"goroutine 26 [running]:\n"}
// {"Time":"2021-01-19T13:46:01.683795-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)","Output":"testing.tRunner.func1.1(0x111d260, 0x116e4c0)\n"}
// {"Time":"2021-01-19T13:46:01.683799-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)","Output":"\t/usr/local/Cellar/go/1.15.6/libexec/src/testing/testing.go:1072 +0x30d\n"}
// {"Time":"2021-01-19T13:46:01.683815-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)","Output":"testing.tRunner.func1(0xc000103500)\n"}
// {"Time":"2021-01-19T13:46:01.683821-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)","Output":"\t/usr/local/Cellar/go/1.15.6/libexec/src/testing/testing.go:1075 +0x41a\n"}
// {"Time":"2021-01-19T13:46:01.683828-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)","Output":"panic(0x111d260, 0x116e4c0)\n"}
// {"Time":"2021-01-19T13:46:01.683852-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)","Output":"\t/usr/local/Cellar/go/1.15.6/libexec/src/runtime/panic.go:969 +0x1b9\n"}
// {"Time":"2021-01-19T13:46:01.683893-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)","Output":"conditionals.IsBlackjack(...)\n"}
// {"Time":"2021-01-19T13:46:01.683903-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)","Output":"\t/Users/ekingery/dev/exercism/go-test-runner/testrunner/testdata/concept/conditionals/conditionals.go:35\n"}
// {"Time":"2021-01-19T13:46:01.683912-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)","Output":"conditionals.TestBlackjack.func1(0xc000103500)\n"}
// {"Time":"2021-01-19T13:46:01.683919-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)","Output":"\t/Users/ekingery/dev/exercism/go-test-runner/testrunner/testdata/concept/conditionals/conditionals_test.go:110 +0x39\n"}
// {"Time":"2021-01-19T13:46:01.683925-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)","Output":"testing.tRunner(0xc000103500, 0xc0001106f0)\n"}
// {"Time":"2021-01-19T13:46:01.683954-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)","Output":"\t/usr/local/Cellar/go/1.15.6/libexec/src/testing/testing.go:1123 +0xef\n"}
// {"Time":"2021-01-19T13:46:01.683965-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)","Output":"created by testing.(*T).Run\n"}
// {"Time":"2021-01-19T13:46:01.683971-06:00","Action":"output","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)","Output":"\t/usr/local/Cellar/go/1.15.6/libexec/src/testing/testing.go:1168 +0x2b3\n"}
// {"Time":"2021-01-19T13:46:01.684418-06:00","Action":"fail","Package":"conditionals","Test":"TestBlackjack/blackjack_with_ten_(ace_first)","Elapsed":0}
// {"Time":"2021-01-19T13:46:01.684452-06:00","Action":"fail","Package":"conditionals","Test":"TestBlackjack","Elapsed":0}
// {"Time":"2021-01-19T13:46:01.68446-06:00","Action":"output","Package":"conditionals","Output":"FAIL\tconditionals\t0.012s\n"}
// {"Time":"2021-01-19T13:46:01.684465-06:00","Action":"fail","Package":"conditionals","Elapsed":0.012}
//
//
// ------
//
// extracted test function:
//  func TestParseCard(t *testing.T) {
// 	tests := []struct {
// 		name	string
// 		card	string
// 		want	int
// 	}{
// 		{
// 			name:	"parse two",
// 			card:	"two",
// 			want:	2,
// 		},
// 		{
// 			name:	"parse jack",
// 			card:	"jack",
// 			want:	10,
// 		},
// 		{
// 			name:	"parse king",
// 			card:	"king",
// 			want:	10,
// 		},
// 	}
// 	for _, tt := range tests {
// 		t.Run(tt.name, func(t *testing.T) {
// 			if got := ParseCard(tt.card); got != tt.want {
// 				t.Errorf("ParseCard(%s) = %d, want %d", tt.card, got, tt.want)
// 			}
// 		})
// 	}
// }
// 509 <nil>

// %%
// Output a pretty printed AST
fset := token.NewFileSet()
f, err := parser.ParseFile(fset, "", "package main\n" + testCodeSrc, parser.ParseComments)
if err != nil {
    log.Fatal(err)
}

fexp, err := parser.ParseExpr(testCodeSrc)
fmt.Println("ast:\n")
ast.Print(fset, fexp)
// Out:
// ast:
//
//      0  *ast.FuncLit {
//      1  .  Type: *ast.FuncType {
//      2  .  .  Func: 1:1
//      3  .  .  Params: *ast.FieldList {
//      4  .  .  .  Opening: 1:6
//      5  .  .  .  List: []*ast.Field (len = 1) {
//      6  .  .  .  .  0: *ast.Field {
//      7  .  .  .  .  .  Names: []*ast.Ident (len = 1) {
//      8  .  .  .  .  .  .  0: *ast.Ident {
//      9  .  .  .  .  .  .  .  NamePos: 2:6
//     10  .  .  .  .  .  .  .  Name: "_"
//     11  .  .  .  .  .  .  .  Obj: *ast.Object {
//     12  .  .  .  .  .  .  .  .  Kind: var
//     13  .  .  .  .  .  .  .  .  Name: "_"
//     14  .  .  .  .  .  .  .  .  Decl: *(obj @ 6)
//     15  .  .  .  .  .  .  .  }
//     16  .  .  .  .  .  .  }
//     17  .  .  .  .  .  }
//     18  .  .  .  .  .  Type: *ast.SelectorExpr {
//     19  .  .  .  .  .  .  X: *ast.Ident {
//     20  .  .  .  .  .  .  .  NamePos: 2:10
//     21  .  .  .  .  .  .  .  Name: "testing"
//     22  .  .  .  .  .  .  .  Obj: *ast.Object {
//     23  .  .  .  .  .  .  .  .  Kind: bad
//     24  .  .  .  .  .  .  .  .  Name: ""
//     25  .  .  .  .  .  .  .  }
//     26  .  .  .  .  .  .  }
//     27  .  .  .  .  .  .  Sel: *ast.Ident {
//     28  .  .  .  .  .  .  .  NamePos: 2:18
//     29  .  .  .  .  .  .  .  Name: "T"
//     30  .  .  .  .  .  .  }
//     31  .  .  .  .  .  }
//     32  .  .  .  .  }
//     33  .  .  .  }
//     34  .  .  .  Closing: 2:19
//     35  .  .  }
//     36  .  }
//     37  .  Body: *ast.BlockStmt {
//     38  .  .  Lbrace: 2:21
//     39  .  .  List: []ast.Stmt (len = 2) {
//     40  .  .  .  0: *ast.AssignStmt {
//     41  .  .  .  .  Lhs: []ast.Expr (len = 1) {
//     42  .  .  .  .  .  0: *ast.Ident {
//     43  .  .  .  .  .  .  NamePos: 2:24
//     44  .  .  .  .  .  .  Name: "tests"
//     45  .  .  .  .  .  .  Obj: *ast.Object {
//     46  .  .  .  .  .  .  .  Kind: var
//     47  .  .  .  .  .  .  .  Name: "tests"
//     48  .  .  .  .  .  .  .  Decl: *(obj @ 40)
//     49  .  .  .  .  .  .  }
//     50  .  .  .  .  .  }
//     51  .  .  .  .  }
//     52  .  .  .  .  TokPos: 2:30
//     53  .  .  .  .  Tok: :=
//     54  .  .  .  .  Rhs: []ast.Expr (len = 1) {
//     55  .  .  .  .  .  0: *ast.CompositeLit {
//     56  .  .  .  .  .  .  Type: *ast.ArrayType {
//     57  .  .  .  .  .  .  .  Lbrack: 2:33
//     58  .  .  .  .  .  .  .  Elt: *ast.StructType {
//     59  .  .  .  .  .  .  .  .  Struct: 2:35
//     60  .  .  .  .  .  .  .  .  Fields: *ast.FieldList {
//     61  .  .  .  .  .  .  .  .  .  Opening: 3:7
//     62  .  .  .  .  .  .  .  .  .  List: []*ast.Field (len = 3) {
//     63  .  .  .  .  .  .  .  .  .  .  0: *ast.Field {
//     64  .  .  .  .  .  .  .  .  .  .  .  Names: []*ast.Ident (len = 1) {
//     65  .  .  .  .  .  .  .  .  .  .  .  .  0: *ast.Ident {
//     66  .  .  .  .  .  .  .  .  .  .  .  .  .  NamePos: 3:11
//     67  .  .  .  .  .  .  .  .  .  .  .  .  .  Name: "name"
//     68  .  .  .  .  .  .  .  .  .  .  .  .  .  Obj: *ast.Object {
//     69  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Kind: var
//     70  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Name: "name"
//     71  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Decl: *(obj @ 63)
//     72  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//     73  .  .  .  .  .  .  .  .  .  .  .  .  }
//     74  .  .  .  .  .  .  .  .  .  .  .  }
//     75  .  .  .  .  .  .  .  .  .  .  .  Type: *ast.Ident {
//     76  .  .  .  .  .  .  .  .  .  .  .  .  NamePos: 3:16
//     77  .  .  .  .  .  .  .  .  .  .  .  .  Name: "string"
//     78  .  .  .  .  .  .  .  .  .  .  .  .  Obj: *(obj @ 22)
//     79  .  .  .  .  .  .  .  .  .  .  .  }
//     80  .  .  .  .  .  .  .  .  .  .  }
//     81  .  .  .  .  .  .  .  .  .  .  1: *ast.Field {
//     82  .  .  .  .  .  .  .  .  .  .  .  Names: []*ast.Ident (len = 1) {
//     83  .  .  .  .  .  .  .  .  .  .  .  .  0: *ast.Ident {
//     84  .  .  .  .  .  .  .  .  .  .  .  .  .  NamePos: 4:4
//     85  .  .  .  .  .  .  .  .  .  .  .  .  .  Name: "card"
//     86  .  .  .  .  .  .  .  .  .  .  .  .  .  Obj: *ast.Object {
//     87  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Kind: var
//     88  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Name: "card"
//     89  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Decl: *(obj @ 81)
//     90  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//     91  .  .  .  .  .  .  .  .  .  .  .  .  }
//     92  .  .  .  .  .  .  .  .  .  .  .  }
//     93  .  .  .  .  .  .  .  .  .  .  .  Type: *ast.Ident {
//     94  .  .  .  .  .  .  .  .  .  .  .  .  NamePos: 4:9
//     95  .  .  .  .  .  .  .  .  .  .  .  .  Name: "string"
//     96  .  .  .  .  .  .  .  .  .  .  .  .  Obj: *(obj @ 22)
//     97  .  .  .  .  .  .  .  .  .  .  .  }
//     98  .  .  .  .  .  .  .  .  .  .  }
//     99  .  .  .  .  .  .  .  .  .  .  2: *ast.Field {
//    100  .  .  .  .  .  .  .  .  .  .  .  Names: []*ast.Ident (len = 1) {
//    101  .  .  .  .  .  .  .  .  .  .  .  .  0: *ast.Ident {
//    102  .  .  .  .  .  .  .  .  .  .  .  .  .  NamePos: 5:4
//    103  .  .  .  .  .  .  .  .  .  .  .  .  .  Name: "want"
//    104  .  .  .  .  .  .  .  .  .  .  .  .  .  Obj: *ast.Object {
//    105  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Kind: var
//    106  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Name: "want"
//    107  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Decl: *(obj @ 99)
//    108  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//    109  .  .  .  .  .  .  .  .  .  .  .  .  }
//    110  .  .  .  .  .  .  .  .  .  .  .  }
//    111  .  .  .  .  .  .  .  .  .  .  .  Type: *ast.Ident {
//    112  .  .  .  .  .  .  .  .  .  .  .  .  NamePos: 5:9
//    113  .  .  .  .  .  .  .  .  .  .  .  .  Name: "int"
//    114  .  .  .  .  .  .  .  .  .  .  .  .  Obj: *(obj @ 22)
//    115  .  .  .  .  .  .  .  .  .  .  .  }
//    116  .  .  .  .  .  .  .  .  .  .  }
//    117  .  .  .  .  .  .  .  .  .  }
//    118  .  .  .  .  .  .  .  .  .  Closing: 5:14
//    119  .  .  .  .  .  .  .  .  }
//    120  .  .  .  .  .  .  .  .  Incomplete: false
//    121  .  .  .  .  .  .  .  }
//    122  .  .  .  .  .  .  }
//    123  .  .  .  .  .  .  Lbrace: 6:1
//    124  .  .  .  .  .  .  Elts: []ast.Expr (len = 3) {
//    125  .  .  .  .  .  .  .  0: *ast.CompositeLit {
//    126  .  .  .  .  .  .  .  .  Lbrace: 6:5
//    127  .  .  .  .  .  .  .  .  Elts: []ast.Expr (len = 3) {
//    128  .  .  .  .  .  .  .  .  .  0: *ast.KeyValueExpr {
//    129  .  .  .  .  .  .  .  .  .  .  Key: *ast.Ident {
//    130  .  .  .  .  .  .  .  .  .  .  .  NamePos: 6:10
//    131  .  .  .  .  .  .  .  .  .  .  .  Name: "name"
//    132  .  .  .  .  .  .  .  .  .  .  }
//    133  .  .  .  .  .  .  .  .  .  .  Colon: 7:3
//    134  .  .  .  .  .  .  .  .  .  .  Value: *ast.BasicLit {
//    135  .  .  .  .  .  .  .  .  .  .  .  ValuePos: 8:1
//    136  .  .  .  .  .  .  .  .  .  .  .  Kind: STRING
//    137  .  .  .  .  .  .  .  .  .  .  .  Value: "\"parse two\""
//    138  .  .  .  .  .  .  .  .  .  .  }
//    139  .  .  .  .  .  .  .  .  .  }
//    140  .  .  .  .  .  .  .  .  .  1: *ast.KeyValueExpr {
//    141  .  .  .  .  .  .  .  .  .  .  Key: *ast.Ident {
//    142  .  .  .  .  .  .  .  .  .  .  .  NamePos: 9:13
//    143  .  .  .  .  .  .  .  .  .  .  .  Name: "card"
//    144  .  .  .  .  .  .  .  .  .  .  }
//    145  .  .  .  .  .  .  .  .  .  .  Colon: 9:17
//    146  .  .  .  .  .  .  .  .  .  .  Value: *ast.BasicLit {
//    147  .  .  .  .  .  .  .  .  .  .  .  ValuePos: 9:19
//    148  .  .  .  .  .  .  .  .  .  .  .  Kind: STRING
//    149  .  .  .  .  .  .  .  .  .  .  .  Value: "\"two\""
//    150  .  .  .  .  .  .  .  .  .  .  }
//    151  .  .  .  .  .  .  .  .  .  }
//    152  .  .  .  .  .  .  .  .  .  2: *ast.KeyValueExpr {
//    153  .  .  .  .  .  .  .  .  .  .  Key: *ast.Ident {
//    154  .  .  .  .  .  .  .  .  .  .  .  NamePos: 10:7
//    155  .  .  .  .  .  .  .  .  .  .  .  Name: "want"
//    156  .  .  .  .  .  .  .  .  .  .  }
//    157  .  .  .  .  .  .  .  .  .  .  Colon: 10:11
//    158  .  .  .  .  .  .  .  .  .  .  Value: *ast.BasicLit {
//    159  .  .  .  .  .  .  .  .  .  .  .  ValuePos: 10:13
//    160  .  .  .  .  .  .  .  .  .  .  .  Kind: INT
//    161  .  .  .  .  .  .  .  .  .  .  .  Value: "2"
//    162  .  .  .  .  .  .  .  .  .  .  }
//    163  .  .  .  .  .  .  .  .  .  }
//    164  .  .  .  .  .  .  .  .  }
//    165  .  .  .  .  .  .  .  .  Rbrace: 11:2
//    166  .  .  .  .  .  .  .  .  Incomplete: false
//    167  .  .  .  .  .  .  .  }
//    168  .  .  .  .  .  .  .  1: *ast.CompositeLit {
//    169  .  .  .  .  .  .  .  .  Lbrace: 11:7
//    170  .  .  .  .  .  .  .  .  Elts: []ast.Expr (len = 3) {
//    171  .  .  .  .  .  .  .  .  .  0: *ast.KeyValueExpr {
//    172  .  .  .  .  .  .  .  .  .  .  Key: *ast.Ident {
//    173  .  .  .  .  .  .  .  .  .  .  .  NamePos: 11:12
//    174  .  .  .  .  .  .  .  .  .  .  .  Name: "name"
//    175  .  .  .  .  .  .  .  .  .  .  }
//    176  .  .  .  .  .  .  .  .  .  .  Colon: 12:4
//    177  .  .  .  .  .  .  .  .  .  .  Value: *ast.BasicLit {
//    178  .  .  .  .  .  .  .  .  .  .  .  ValuePos: 13:1
//    179  .  .  .  .  .  .  .  .  .  .  .  Kind: STRING
//    180  .  .  .  .  .  .  .  .  .  .  .  Value: "\"parse jack\""
//    181  .  .  .  .  .  .  .  .  .  .  }
//    182  .  .  .  .  .  .  .  .  .  }
//    183  .  .  .  .  .  .  .  .  .  1: *ast.KeyValueExpr {
//    184  .  .  .  .  .  .  .  .  .  .  Key: *ast.Ident {
//    185  .  .  .  .  .  .  .  .  .  .  .  NamePos: 14:14
//    186  .  .  .  .  .  .  .  .  .  .  .  Name: "card"
//    187  .  .  .  .  .  .  .  .  .  .  }
//    188  .  .  .  .  .  .  .  .  .  .  Colon: 14:18
//    189  .  .  .  .  .  .  .  .  .  .  Value: *ast.BasicLit {
//    190  .  .  .  .  .  .  .  .  .  .  .  ValuePos: 14:20
//    191  .  .  .  .  .  .  .  .  .  .  .  Kind: STRING
//    192  .  .  .  .  .  .  .  .  .  .  .  Value: "\"jack\""
//    193  .  .  .  .  .  .  .  .  .  .  }
//    194  .  .  .  .  .  .  .  .  .  }
//    195  .  .  .  .  .  .  .  .  .  2: *ast.KeyValueExpr {
//    196  .  .  .  .  .  .  .  .  .  .  Key: *ast.Ident {
//    197  .  .  .  .  .  .  .  .  .  .  .  NamePos: 15:8
//    198  .  .  .  .  .  .  .  .  .  .  .  Name: "want"
//    199  .  .  .  .  .  .  .  .  .  .  }
//    200  .  .  .  .  .  .  .  .  .  .  Colon: 15:12
//    201  .  .  .  .  .  .  .  .  .  .  Value: *ast.BasicLit {
//    202  .  .  .  .  .  .  .  .  .  .  .  ValuePos: 15:14
//    203  .  .  .  .  .  .  .  .  .  .  .  Kind: INT
//    204  .  .  .  .  .  .  .  .  .  .  .  Value: "10"
//    205  .  .  .  .  .  .  .  .  .  .  }
//    206  .  .  .  .  .  .  .  .  .  }
//    207  .  .  .  .  .  .  .  .  }
//    208  .  .  .  .  .  .  .  .  Rbrace: 16:3
//    209  .  .  .  .  .  .  .  .  Incomplete: false
//    210  .  .  .  .  .  .  .  }
//    211  .  .  .  .  .  .  .  2: *ast.CompositeLit {
//    212  .  .  .  .  .  .  .  .  Lbrace: 16:8
//    213  .  .  .  .  .  .  .  .  Elts: []ast.Expr (len = 3) {
//    214  .  .  .  .  .  .  .  .  .  0: *ast.KeyValueExpr {
//    215  .  .  .  .  .  .  .  .  .  .  Key: *ast.Ident {
//    216  .  .  .  .  .  .  .  .  .  .  .  NamePos: 16:13
//    217  .  .  .  .  .  .  .  .  .  .  .  Name: "name"
//    218  .  .  .  .  .  .  .  .  .  .  }
//    219  .  .  .  .  .  .  .  .  .  .  Colon: 17:4
//    220  .  .  .  .  .  .  .  .  .  .  Value: *ast.BasicLit {
//    221  .  .  .  .  .  .  .  .  .  .  .  ValuePos: 18:1
//    222  .  .  .  .  .  .  .  .  .  .  .  Kind: STRING
//    223  .  .  .  .  .  .  .  .  .  .  .  Value: "\"parse king\""
//    224  .  .  .  .  .  .  .  .  .  .  }
//    225  .  .  .  .  .  .  .  .  .  }
//    226  .  .  .  .  .  .  .  .  .  1: *ast.KeyValueExpr {
//    227  .  .  .  .  .  .  .  .  .  .  Key: *ast.Ident {
//    228  .  .  .  .  .  .  .  .  .  .  .  NamePos: 19:14
//    229  .  .  .  .  .  .  .  .  .  .  .  Name: "card"
//    230  .  .  .  .  .  .  .  .  .  .  }
//    231  .  .  .  .  .  .  .  .  .  .  Colon: 19:18
//    232  .  .  .  .  .  .  .  .  .  .  Value: *ast.BasicLit {
//    233  .  .  .  .  .  .  .  .  .  .  .  ValuePos: 19:20
//    234  .  .  .  .  .  .  .  .  .  .  .  Kind: STRING
//    235  .  .  .  .  .  .  .  .  .  .  .  Value: "\"king\""
//    236  .  .  .  .  .  .  .  .  .  .  }
//    237  .  .  .  .  .  .  .  .  .  }
//    238  .  .  .  .  .  .  .  .  .  2: *ast.KeyValueExpr {
//    239  .  .  .  .  .  .  .  .  .  .  Key: *ast.Ident {
//    240  .  .  .  .  .  .  .  .  .  .  .  NamePos: 20:8
//    241  .  .  .  .  .  .  .  .  .  .  .  Name: "want"
//    242  .  .  .  .  .  .  .  .  .  .  }
//    243  .  .  .  .  .  .  .  .  .  .  Colon: 20:12
//    244  .  .  .  .  .  .  .  .  .  .  Value: *ast.BasicLit {
//    245  .  .  .  .  .  .  .  .  .  .  .  ValuePos: 20:14
//    246  .  .  .  .  .  .  .  .  .  .  .  Kind: INT
//    247  .  .  .  .  .  .  .  .  .  .  .  Value: "10"
//    248  .  .  .  .  .  .  .  .  .  .  }
//    249  .  .  .  .  .  .  .  .  .  }
//    250  .  .  .  .  .  .  .  .  }
//    251  .  .  .  .  .  .  .  .  Rbrace: 21:3
//    252  .  .  .  .  .  .  .  .  Incomplete: false
//    253  .  .  .  .  .  .  .  }
//    254  .  .  .  .  .  .  }
//    255  .  .  .  .  .  .  Rbrace: 21:7
//    256  .  .  .  .  .  .  Incomplete: false
//    257  .  .  .  .  .  }
//    258  .  .  .  .  }
//    259  .  .  .  }
//    260  .  .  .  1: *ast.RangeStmt {
//    261  .  .  .  .  For: 21:10
//    262  .  .  .  .  Key: *ast.Ident {
//    263  .  .  .  .  .  NamePos: 22:1
//    264  .  .  .  .  .  Name: "_"
//    265  .  .  .  .  .  Obj: *ast.Object {
//    266  .  .  .  .  .  .  Kind: var
//    267  .  .  .  .  .  .  Name: "_"
//    268  .  .  .  .  .  .  Decl: *ast.AssignStmt {
//    269  .  .  .  .  .  .  .  Lhs: []ast.Expr (len = 2) {
//    270  .  .  .  .  .  .  .  .  0: *(obj @ 262)
//    271  .  .  .  .  .  .  .  .  1: *ast.Ident {
//    272  .  .  .  .  .  .  .  .  .  NamePos: 22:4
//    273  .  .  .  .  .  .  .  .  .  Name: "tt"
//    274  .  .  .  .  .  .  .  .  .  Obj: *ast.Object {
//    275  .  .  .  .  .  .  .  .  .  .  Kind: var
//    276  .  .  .  .  .  .  .  .  .  .  Name: "tt"
//    277  .  .  .  .  .  .  .  .  .  .  Decl: *(obj @ 268)
//    278  .  .  .  .  .  .  .  .  .  }
//    279  .  .  .  .  .  .  .  .  }
//    280  .  .  .  .  .  .  .  }
//    281  .  .  .  .  .  .  .  TokPos: 23:2
//    282  .  .  .  .  .  .  .  Tok: :=
//    283  .  .  .  .  .  .  .  Rhs: []ast.Expr (len = 1) {
//    284  .  .  .  .  .  .  .  .  0: *ast.UnaryExpr {
//    285  .  .  .  .  .  .  .  .  .  OpPos: 24:2
//    286  .  .  .  .  .  .  .  .  .  Op: range
//    287  .  .  .  .  .  .  .  .  .  X: *ast.Ident {
//    288  .  .  .  .  .  .  .  .  .  .  NamePos: 24:8
//    289  .  .  .  .  .  .  .  .  .  .  Name: "tests"
//    290  .  .  .  .  .  .  .  .  .  .  Obj: *(obj @ 45)
//    291  .  .  .  .  .  .  .  .  .  }
//    292  .  .  .  .  .  .  .  .  }
//    293  .  .  .  .  .  .  .  }
//    294  .  .  .  .  .  .  }
//    295  .  .  .  .  .  }
//    296  .  .  .  .  }
//    297  .  .  .  .  Value: *(obj @ 271)
//    298  .  .  .  .  TokPos: 23:2
//    299  .  .  .  .  Tok: :=
//    300  .  .  .  .  X: *(obj @ 287)
//    301  .  .  .  .  Body: *ast.BlockStmt {
//    302  .  .  .  .  .  Lbrace: 24:14
//    303  .  .  .  .  .  List: []ast.Stmt (len = 1) {
//    304  .  .  .  .  .  .  0: *ast.ExprStmt {
//    305  .  .  .  .  .  .  .  X: *ast.CallExpr {
//    306  .  .  .  .  .  .  .  .  Fun: *ast.SelectorExpr {
//    307  .  .  .  .  .  .  .  .  .  X: *ast.Ident {
//    308  .  .  .  .  .  .  .  .  .  .  NamePos: 24:18
//    309  .  .  .  .  .  .  .  .  .  .  Name: "t"
//    310  .  .  .  .  .  .  .  .  .  .  Obj: *(obj @ 22)
//    311  .  .  .  .  .  .  .  .  .  }
//    312  .  .  .  .  .  .  .  .  .  Sel: *ast.Ident {
//    313  .  .  .  .  .  .  .  .  .  .  NamePos: 24:20
//    314  .  .  .  .  .  .  .  .  .  .  Name: "Run"
//    315  .  .  .  .  .  .  .  .  .  }
//    316  .  .  .  .  .  .  .  .  }
//    317  .  .  .  .  .  .  .  .  Lparen: 24:23
//    318  .  .  .  .  .  .  .  .  Args: []ast.Expr (len = 2) {
//    319  .  .  .  .  .  .  .  .  .  0: *ast.SelectorExpr {
//    320  .  .  .  .  .  .  .  .  .  .  X: *ast.Ident {
//    321  .  .  .  .  .  .  .  .  .  .  .  NamePos: 24:24
//    322  .  .  .  .  .  .  .  .  .  .  .  Name: "tt"
//    323  .  .  .  .  .  .  .  .  .  .  .  Obj: *(obj @ 274)
//    324  .  .  .  .  .  .  .  .  .  .  }
//    325  .  .  .  .  .  .  .  .  .  .  Sel: *ast.Ident {
//    326  .  .  .  .  .  .  .  .  .  .  .  NamePos: 24:27
//    327  .  .  .  .  .  .  .  .  .  .  .  Name: "name"
//    328  .  .  .  .  .  .  .  .  .  .  }
//    329  .  .  .  .  .  .  .  .  .  }
//    330  .  .  .  .  .  .  .  .  .  1: *ast.FuncLit {
//    331  .  .  .  .  .  .  .  .  .  .  Type: *ast.FuncType {
//    332  .  .  .  .  .  .  .  .  .  .  .  Func: 25:5
//    333  .  .  .  .  .  .  .  .  .  .  .  Params: *ast.FieldList {
//    334  .  .  .  .  .  .  .  .  .  .  .  .  Opening: 25:9
//    335  .  .  .  .  .  .  .  .  .  .  .  .  List: []*ast.Field (len = 1) {
//    336  .  .  .  .  .  .  .  .  .  .  .  .  .  0: *ast.Field {
//    337  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Names: []*ast.Ident (len = 1) {
//    338  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  0: *ast.Ident {
//    339  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  NamePos: 25:10
//    340  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Name: "t"
//    341  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Obj: *ast.Object {
//    342  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Kind: var
//    343  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Name: "t"
//    344  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Decl: *(obj @ 336)
//    345  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//    346  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//    347  .  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//    348  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Type: *ast.StarExpr {
//    349  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Star: 25:12
//    350  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  X: *ast.SelectorExpr {
//    351  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  X: *ast.Ident {
//    352  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  NamePos: 25:13
//    353  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Name: "testing"
//    354  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Obj: *(obj @ 22)
//    355  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//    356  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Sel: *ast.Ident {
//    357  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  NamePos: 25:21
//    358  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Name: "T"
//    359  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//    360  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//    361  .  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//    362  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//    363  .  .  .  .  .  .  .  .  .  .  .  .  }
//    364  .  .  .  .  .  .  .  .  .  .  .  .  Closing: 25:22
//    365  .  .  .  .  .  .  .  .  .  .  .  }
//    366  .  .  .  .  .  .  .  .  .  .  }
//    367  .  .  .  .  .  .  .  .  .  .  Body: *ast.BlockStmt {
//    368  .  .  .  .  .  .  .  .  .  .  .  Lbrace: 25:24
//    369  .  .  .  .  .  .  .  .  .  .  .  List: []ast.Stmt (len = 1) {
//    370  .  .  .  .  .  .  .  .  .  .  .  .  0: *ast.IfStmt {
//    371  .  .  .  .  .  .  .  .  .  .  .  .  .  If: 25:29
//    372  .  .  .  .  .  .  .  .  .  .  .  .  .  Init: *ast.AssignStmt {
//    373  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Lhs: []ast.Expr (len = 1) {
//    374  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  0: *ast.Ident {
//    375  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  NamePos: 25:32
//    376  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Name: "got"
//    377  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Obj: *ast.Object {
//    378  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Kind: var
//    379  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Name: "got"
//    380  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Decl: *(obj @ 372)
//    381  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//    382  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//    383  .  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//    384  .  .  .  .  .  .  .  .  .  .  .  .  .  .  TokPos: 25:36
//    385  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Tok: :=
//    386  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Rhs: []ast.Expr (len = 1) {
//    387  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  0: *ast.CallExpr {
//    388  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Fun: *ast.Ident {
//    389  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  NamePos: 26:1
//    390  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Name: "ParseCard"
//    391  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Obj: *(obj @ 22)
//    392  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//    393  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Lparen: 26:10
//    394  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Args: []ast.Expr (len = 1) {
//    395  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  0: *ast.SelectorExpr {
//    396  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  X: *ast.Ident {
//    397  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  NamePos: 26:11
//    398  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Name: "tt"
//    399  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Obj: *(obj @ 274)
//    400  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//    401  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Sel: *ast.Ident {
//    402  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  NamePos: 26:14
//    403  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Name: "card"
//    404  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//    405  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//    406  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//    407  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Ellipsis: -
//    408  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Rparen: 26:18
//    409  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//    410  .  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//    411  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//    412  .  .  .  .  .  .  .  .  .  .  .  .  .  Cond: *ast.BinaryExpr {
//    413  .  .  .  .  .  .  .  .  .  .  .  .  .  .  X: *ast.Ident {
//    414  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  NamePos: 26:21
//    415  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Name: "got"
//    416  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Obj: *(obj @ 377)
//    417  .  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//    418  .  .  .  .  .  .  .  .  .  .  .  .  .  .  OpPos: 26:25
//    419  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Op: !=
//    420  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Y: *ast.SelectorExpr {
//    421  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  X: *ast.Ident {
//    422  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  NamePos: 26:28
//    423  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Name: "tt"
//    424  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Obj: *(obj @ 274)
//    425  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//    426  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Sel: *ast.Ident {
//    427  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  NamePos: 26:31
//    428  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Name: "want"
//    429  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//    430  .  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//    431  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//    432  .  .  .  .  .  .  .  .  .  .  .  .  .  Body: *ast.BlockStmt {
//    433  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Lbrace: 26:36
//    434  .  .  .  .  .  .  .  .  .  .  .  .  .  .  List: []ast.Stmt (len = 1) {
//    435  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  0: *ast.ExprStmt {
//    436  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  X: *ast.CallExpr {
//    437  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Fun: *ast.SelectorExpr {
//    438  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  X: *ast.Ident {
//    439  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  NamePos: 26:42
//    440  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Name: "t"
//    441  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Obj: *(obj @ 341)
//    442  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//    443  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Sel: *ast.Ident {
//    444  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  NamePos: 26:44
//    445  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Name: "Errorf"
//    446  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//    447  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//    448  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Lparen: 26:50
//    449  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Args: []ast.Expr (len = 4) {
//    450  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  0: *ast.BasicLit {
//    451  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  ValuePos: 27:1
//    452  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Kind: STRING
//    453  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Value: "\"ParseCard(%s) = %d, want %d\""
//    454  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//    455  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  1: *ast.SelectorExpr {
//    456  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  X: *ast.Ident {
//    457  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  NamePos: 27:32
//    458  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Name: "tt"
//    459  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Obj: *(obj @ 274)
//    460  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//    461  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Sel: *ast.Ident {
//    462  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  NamePos: 27:35
//    463  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Name: "card"
//    464  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//    465  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//    466  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  2: *ast.Ident {
//    467  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  NamePos: 27:41
//    468  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Name: "got"
//    469  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Obj: *(obj @ 377)
//    470  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//    471  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  3: *ast.SelectorExpr {
//    472  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  X: *ast.Ident {
//    473  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  NamePos: 27:46
//    474  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Name: "tt"
//    475  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Obj: *(obj @ 274)
//    476  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//    477  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Sel: *ast.Ident {
//    478  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  NamePos: 27:49
//    479  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Name: "want"
//    480  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//    481  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//    482  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//    483  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Ellipsis: -
//    484  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Rparen: 27:53
//    485  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//    486  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//    487  .  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//    488  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Rbrace: 27:58
//    489  .  .  .  .  .  .  .  .  .  .  .  .  .  }
//    490  .  .  .  .  .  .  .  .  .  .  .  .  }
//    491  .  .  .  .  .  .  .  .  .  .  .  }
//    492  .  .  .  .  .  .  .  .  .  .  .  Rbrace: 27:62
//    493  .  .  .  .  .  .  .  .  .  .  }
//    494  .  .  .  .  .  .  .  .  .  }
//    495  .  .  .  .  .  .  .  .  }
//    496  .  .  .  .  .  .  .  .  Ellipsis: -
//    497  .  .  .  .  .  .  .  .  Rparen: 27:63
//    498  .  .  .  .  .  .  .  }
//    499  .  .  .  .  .  .  }
//    500  .  .  .  .  .  }
//    501  .  .  .  .  .  Rbrace: 27:66
//    502  .  .  .  .  }
//    503  .  .  .  }
//    504  .  .  }
//    505  .  .  Rbrace: 28:1
//    506  .  }
//    507  }

// %%
// This code most closely resembles the implementation (as of jan 2021)
// It "manually" traverses the AST based on an expected structure
// defined by the spec - see the README for details: 
// https://github.com/exercism/go-test-runner/blob/master/README.md#subtest-format-specification
cwd, err := os.Getwd()
if err != nil {
    fmt.Println(err)
}
input_dir := cwd + "/testdata/concept/conditionals"
output_dir := cwd + "/outdir"
testName := "TestParseCard"
testFile := cwd + "/testdata/concept/conditionals/conditionals_test.go"
testCodeSrc := testrunner.ExtractTestCode(testName, testFile)
//fmt.Println(testCodeSrc)

fset := token.NewFileSet()
f, err := parser.ParseFile(fset, testFile, "package main\n" + testCodeSrc, parser.ParseComments)
if err != nil {
    log.Fatal(err)
}
//ast.Print(fset, f)

type testMeta struct {
    subTName    string             // name of subtest
    subTKey     string             // subtest name key
    origTDName  string             // original test data []struct name
    newTDName   string             // new test data struct name
    TD          []ast.Expr         // original tests data node
    subTest     ast.Stmt           // Run() function literal node
} 

metadata := testMeta{
    subTName: "parse queen",
}

fAST, ok := f.Decls[0].(*ast.FuncDecl)
if !ok {
    fmt.Println("subtest does not contain a function as the first declaration") 
}
fbAST := fAST.Body.List  // f.Decls[0].Body.List*/

if 2 != len(fbAST) {
    fmt.Println("subtests are constrained to two top level nodes") 
}

tdast, ok := fbAST[0].(*ast.AssignStmt) // f.Decls[0].Body.List[0]
if !ok {
    fmt.Println("subtest does not contain a test data assignment as the first node") 
}
rast, ok := fbAST[1].(*ast.RangeStmt)
if !ok {
    fmt.Println("subtest does not contain a range keyword as the second node") 
}

// Go to work on the test data assignment
lhs1, ok := tdast.Lhs[0].(*ast.Ident) // f.Decls[0].Body.List[0].Lhs[0]
if !ok {
    fmt.Println("subtest test data assignment not found") 
}
if ast.Var != lhs1.Obj.Kind {
    fmt.Println("subtest test data assignment not a var") 
}
metadata.origTDName = lhs1.Name

rhs1, ok := tdast.Rhs[0].(*ast.CompositeLit) // f.Decls[0].Body.List[0].Rhs[0]
if !ok {
    fmt.Println("subtest test data assignment not a composite literal") 
}


// Loop for all of the test data structs
for i, td := range rhs1.Elts {
    vals, ok := td.(*ast.CompositeLit)
    if ok {
        // Loop for each KeyValueExpr in the struct
        for _, tv := range vals.Elts {
            if kv, ok := tv.(*ast.KeyValueExpr); ok {
                if value, ok := kv.Value.(*ast.BasicLit); ok {
                    // [TODO] https://github.com/golang/go/blob/f1980efb92c011eab71aa61b68ccf58d845d1de7/src/testing/match.go#L50
                    altSubTName := strings.Replace(metadata.subTName, " ", "_", -1)
                    if token.STRING == value.Kind && (strconv.Quote(metadata.subTName) == value.Value || strconv.Quote(altSubTName) == value.Value) {
                        // Store the parent array of KeyValueExprs 
                        //  - this is the test data element for the requested subtest
                        metadata.TD = vals.Elts
                        // Store the subtest data "name" value
                        metadata.subTKey = kv.Key.(*ast.Ident).Name
                    }
                }
            }
        }
    }
}

// Go to work on the range statement

// Confirm that the range is over the test data
if (rast.X.(*ast.Ident).Name != metadata.origTDName) {
    fmt.Printf("mismatch between test data (%s) and range value (%s)", rast.X.(*ast.Ident).Name, metadata.origTDName)
}

// Pull the name of the subtest data being used
metadata.newTDName = rast.Value.(*ast.Ident).Name

// Parse out the Run() call within the range statement
rblexp := rast.Body.List[0].(*ast.ExprStmt).X

// Parse out the function literal from the Run() call within the range statement
runcall := rblexp.(*ast.CallExpr).Fun

if ("Run" != runcall.(*ast.SelectorExpr).Sel.Name) {
    fmt.Printf("Run() call did not follow range loop: (%s)", runcall.(*ast.SelectorExpr).Sel.Name)
}

runselector := rblexp.(*ast.CallExpr).Args[0]
runfunclit := rblexp.(*ast.CallExpr).Args[1]


if (metadata.newTDName != runselector.(*ast.SelectorExpr).X.(*ast.Ident).Name) {
    fmt.Printf("Run() call not passing expected test data %s: %s", metadata.newTDName, runselector.(*ast.SelectorExpr).X.(*ast.Ident).Name)
}

if (metadata.subTKey != runselector.(*ast.SelectorExpr).Sel.Name) {
    fmt.Printf("Run() call name (%s) does not match name from test data struct: %s", runselector.(*ast.SelectorExpr).X.(*ast.Ident).Name, metadata.subTKey)
}

body := runfunclit.(*ast.FuncLit).Body.List[0]
metadata.subTest = body

// rhs1, ok := tdast.Rhs[0].(*ast.CompositeLit) // f.Decls[0].Body.List[0].Rhs[0]

rhstype := rhs1.Type.(*ast.ArrayType) //Elt.(*ast.StructType)
//rhsstruct := rhstype.Elt
//rhs1.Type = rhsstruct

rhs1.Type = rhs1.Type.(*ast.ArrayType).Elt

fmt.Printf("rhstypelt %T | %+v\n", rhstype, rhstype)

rhs1.Elts = metadata.TD
//tdast.Rhs = metadata.TD

/*  69  .  .  .  .  .  .  Rhs: []ast.Expr (len = 1) {
    70  .  .  .  .  .  .  .  0: *ast.CompositeLit {
    71  .  .  .  .  .  .  .  .  Type: *ast.ArrayType {
    72  .  .  .  .  .  .  .  .  .  Lbrack: ~/dev/exercism/go-test-runner/testdata/concept/conditionals/conditionals_test.go:3:11
    73  .  .  .  .  .  .  .  .  .  Elt: *ast.StructType {*/


lhs1.Name = metadata.newTDName

assgn := &ast.AssignStmt{
    Lhs: []ast.Expr{lhs1},
    TokPos: tdast.TokPos,
    Tok:    tdast.Tok,
    Rhs: []ast.Expr{rhs1},
}
tdast = assgn

fbAST[1] = metadata.subTest

fmt.Printf("%+v\n--\n", metadata)
//fmt.Printf("%T | %+v\n", rhs.Elts, rhs.Elts)

var buf bytes.Buffer
fmt.Printf("type %T: %s", metadata.TD, buf.String())
if err := format.Node(&buf, fset, f); err != nil {
    panic(err)
}
fmt.Printf("output node: %s", buf.String())
// Out:
// Run() call name (tt) does not match name from test data struct: rhstypelt *ast.ArrayType | &{Lbrack:59 Len:<nil> Elt:0xc000844d80}
// {𒀸subTName:parse queen 𒀸subTKey: 𒀸origTDName:tests 𒀸newTDName:tt TD:[] 𒀸subTest:0xc00083f6c0}
// --
// type []ast.Expr: output node: package main
//
// func TestParseCard(t *testing.T) {
// 	tt := struct {
// 		name string
// 		card string
// 		want int
// 	}{}
//
// 	if got := ParseCard(tt.card); got != tt.want {
// 		t.Errorf("ParseCard(%s) = %d, want %d", tt.card, got, tt.want)
// 	}
//
// }
// 242 <nil>

// %%
// This code uses the Apply function to iterate over the AST
// Both Apply and Inspect might be useful in providing more flexible parsing code,
// not reliant on a simple subtest meeting the spec (see link in the cell above)
astutil.Apply(fexp, func(cr *astutil.Cursor) bool {
    n := cr.Node()
    //n := cr.Parent()
    switch x := n.(type) {
    case *ast.BasicLit:
        if token.STRING == x.Kind && "\"parse queen\"" == x.Value{
            fmt.Printf("bl %s:\t%s - %s\n", fset.Position(n.Pos()), x.Kind, x.Value)
            //tdAssgn = cr.Parent()
            //tdPNode = cr.Parent()
            //return false
        }
    case *ast.AssignStmt:
        fmt.Printf("asgn %s: %s - %s\n", fset.Position(n.Pos()), x.Lhs, x.Rhs)
        //tda = *x
        //tdn = n
    case *ast.ExprStmt:
        if x != nil {
            fmt.Printf("exprst %s: %s - %s\n", fset.Position(n.Pos()), x.X, "")
        }
	}
	return true
}, nil)

//var abuf bytes.Buffer
//printer.Fprint(&abuf, fset, fexp)
//fmt.Println("after\n----\n", abuf.String())
// Out:
// asgn /Users/ekingery/dev/exercism/go-test-runner/testrunner/testdata/concept/conditionals/conditionals_test.go:2:24: [tests] - [%!s(*ast.CompositeLit=&{0xc00050b500 98 [0xc0005574c0 0xc000557540 0xc0005575c0] 284 false})]
// exprst /Users/ekingery/dev/exercism/go-test-runner/testrunner/testdata/concept/conditionals/conditionals_test.go:24:18: &{%!s(*ast.SelectorExpr=&{0xc000501ee0 0xc000501f00}) %!s(token.Pos=321) [%!s(*ast.SelectorExpr=&{0xc000501f40 0xc000501f60}) %!s(*ast.FuncLit=&{0xc00056c040 0xc00050b8c0})] %!s(token.Pos=0) %!s(token.Pos=477)} -
// asgn /Users/ekingery/dev/exercism/go-test-runner/testrunner/testdata/concept/conditionals/conditionals_test.go:25:32: [got] - [%!s(*ast.CallExpr=&{0xc00056c080 374 [0xc00056c0e0] 0 382})]
// exprst /Users/ekingery/dev/exercism/go-test-runner/testrunner/testdata/concept/conditionals/conditionals_test.go:26:42: &{%!s(*ast.SelectorExpr=&{0xc00056c180 0xc00056c1a0}) %!s(token.Pos=414) [%!s(*ast.BasicLit=&{415 9 "ParseCard(%s) = %d, want %d"}) %!s(*ast.SelectorExpr=&{0xc00056c200 0xc00056c220}) got %!s(*ast.SelectorExpr=&{0xc00056c2a0 0xc00056c2c0})] %!s(token.Pos=0) %!s(token.Pos=467)} -
// &{0xc000501a00 0xc00050b920}

// %%
// This code uses the Inspect function to iterate over the AST
type testMeta struct {
    subTName    string           // name of subtest
    origTDName  string           // original test data []struct name
    newTDName   string           // new test data struct name
    TDAssign    ast.Node         // tests AssignStmt
    subTest     ast.CompositeLit // Run() function literal node
    rangeStmt   ast.RangeStmt    // test loop range statement node
} 

metadata := testMeta{
    subTName: "parse queen",
}

fset := token.NewFileSet()
f, err := parser.ParseFile(fset, "", "package main\n" + testCodeSrc, parser.ParseComments)
if err != nil {
    log.Fatal(err)
}
fexp, err := parser.ParseExpr(testCodeSrc)

ast.Inspect(fexp, func(n ast.Node) bool {
    switch x := n.(type) {
    case *ast.RangeStmt:        
        fmt.Printf("range %s:\t%s - %s\n", fset.Position(n.Pos()), x.X, x.Body)

    case *ast.BasicLit:
        if token.STRING == x.Kind && "\"parse queen\"" == x.Value {
            fmt.Printf("bl %s:\t%s - %s\n", fset.Position(n.Pos()), x.Kind, x.Value)
            //tdAssgn = cr.Parent()
            //tdPNode = cr.Parent()
            metadata.origTDName = "parse queen"
            //return false
        }
    case *ast.AssignStmt:
        if metadata.TDAssign == nil {
            //[TODO - search and assign]
            fmt.Printf("asgn %s: %s - %s\n", fset.Position(n.Pos()), x.Lhs, x.Rhs)
            metadata.TDAssign = n
        }
    }
    return true
})

fmt.Println("-----\n")
fmt.Printf("%+v\n", metadata)
fmt.Println("-----\n")
//fexp, err := parser.ParseExpr(testCodeSrc)
//fmt.Println(testCodeSrc)
// Out:
// asgn 2:24: [tests] - [%!s(*ast.CompositeLit=&{0xc000948ff0 98 [0xc000945440 0xc0009454c0 0xc000945540] 284 false})]
// range 21:10:	tests - &{%!s(token.Pos=312) [%!s(*ast.ExprStmt=&{0xc000945800})] %!s(token.Pos=480)}
// -----
//
// {𒀸subTName:parse queen 𒀸origTDName: 𒀸newTDName: TDAssign:0xc000945600 𒀸subTest:{Type:<nil> Lbrace:0 Elts:[] Rbrace:0 Incomplete:false} 𒀸rangeStmt:{For:0 Key:<nil> Value:<nil> TokPos:0 Tok:ILLEGAL X:<nil> Body:<nil>}}
// -----
// 7 <nil>
